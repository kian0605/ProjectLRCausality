# %%
# %reset -f

# %%
import pickle
import numpy as np
import pandas as pd
path = '/home/kian/Dropbox/MATLAB/2019/LongRunCausality/Python'
with open(path+'/sim_res.pickle', 'rb') as f:
    size = pickle.load(f)['size']
with open(path+'/sim_res.pickle', 'rb') as f:
    power0 = pickle.load(f)['power0']
with open(path+'/sim_res.pickle', 'rb') as f:
    power1 = pickle.load(f)['power1']

# case1
table1 = pd.DataFrame(np.concatenate((size[:,:,0,0,0],size[:,:,1,0,0],size[:,:,2,0,0],size[:,:,3,0,0],size[:,:,4,0,0]),0))
print(pd.DataFrame.to_latex(table1,index=False, header=False))#%%
# case2
table2 = pd.DataFrame(np.concatenate((size[:,:,0,0,1],size[:,:,1,0,1],size[:,:,2,0,1],size[:,:,3,0,1],size[:,:,4,0,1]),0))
print(pd.DataFrame.to_latex(table2,index=False, header=False))
# Out:
# \begin{tabular}{rrr}
# \toprule
#  0.618 &  0.478 &  0.229 \\
#  0.541 &  0.359 &  0.110 \\
#  0.423 &  0.262 &  0.087 \\
#  0.365 &  0.242 &  0.081 \\
#  0.298 &  0.201 &  0.066 \\
#  0.249 &  0.173 &  0.056 \\
#  0.581 &  0.365 &  0.083 \\
#  0.431 &  0.298 &  0.081 \\
#  0.340 &  0.227 &  0.082 \\
#  0.254 &  0.172 &  0.067 \\
#  0.241 &  0.151 &  0.050 \\
#  0.171 &  0.097 &  0.042 \\
#  0.515 &  0.357 &  0.112 \\
#  0.320 &  0.230 &  0.095 \\
#  0.245 &  0.157 &  0.045 \\
#  0.188 &  0.115 &  0.026 \\
#  0.156 &  0.090 &  0.023 \\
#  0.154 &  0.090 &  0.034 \\
#  0.390 &  0.262 &  0.093 \\
#  0.206 &  0.136 &  0.048 \\
#  0.159 &  0.088 &  0.023 \\
#  0.145 &  0.082 &  0.021 \\
#  0.144 &  0.077 &  0.020 \\
#  0.110 &  0.058 &  0.014 \\
#  0.231 &  0.134 &  0.031 \\
#  0.157 &  0.085 &  0.019 \\
#  0.133 &  0.065 &  0.013 \\
#  0.105 &  0.052 &  0.009 \\
#  0.107 &  0.051 &  0.011 \\
#  0.110 &  0.062 &  0.015 \\
# \bottomrule
# \end{tabular}
#
# \begin{tabular}{rrr}
# \toprule
# ...

# %%
table31 = pd.DataFrame(np.concatenate((power0[:,2:,0,0,2],power0[:,2:,1,0,2],power0[:,2:,2,0,2],power0[:,2:,3,0,2],power0[:,2:,4,0,2]),0))
table32 = pd.DataFrame(np.concatenate((power0[:,2:,0,1,2],power0[:,2:,1,1,2],power0[:,2:,2,1,2],power0[:,2:,3,1,2],power0[:,2:,4,1,2]),0))
table33 = pd.DataFrame(np.concatenate((power0[:,2:,0,2,2],power0[:,2:,1,2,2],power0[:,2:,2,2,2],power0[:,2:,3,2,2],power0[:,2:,4,2,2]),0))
table3a = pd.concat((table31,table32,table33),1)
table31 = pd.DataFrame(np.concatenate((power1[:,2:,0,0,2],power1[:,2:,1,0,2],power1[:,2:,2,0,2],power1[:,2:,3,0,2],power1[:,2:,4,0,2]),0))
table32 = pd.DataFrame(np.concatenate((power1[:,2:,0,1,2],power1[:,2:,1,1,2],power1[:,2:,2,1,2],power1[:,2:,3,1,2],power1[:,2:,4,1,2]),0))
table33 = pd.DataFrame(np.concatenate((power1[:,2:,0,2,2],power1[:,2:,1,2,2],power1[:,2:,2,2,2],power1[:,2:,3,2,2],power1[:,2:,4,2,2]),0))
table3b = pd.concat((table31,table32,table33),1)
table3 = pd.concat((table3a,table3b),1)
print(pd.DataFrame.to_latex(table3,index=False, header=False))
# Out:
# \begin{tabular}{rrrrrr}
# \toprule
#  0.993 &  0.991 &  0.996 &  0.245 &  0.242 &  0.259 \\
#  0.712 &  0.754 &  0.897 &  0.168 &  0.190 &  0.357 \\
#  0.470 &  0.643 &  0.948 &  0.145 &  0.238 &  0.695 \\
#  0.331 &  0.611 &  0.972 &  0.162 &  0.385 &  0.930 \\
#  0.323 &  0.727 &  0.998 &  0.171 &  0.539 &  0.988 \\
#  0.298 &  0.812 &  1.000 &  0.173 &  0.691 &  0.999 \\
#  0.833 &  0.863 &  0.962 &  0.143 &  0.120 &  0.268 \\
#  0.385 &  0.614 &  0.972 &  0.157 &  0.321 &  0.909 \\
#  0.275 &  0.748 &  1.000 &  0.183 &  0.616 &  0.998 \\
#  0.294 &  0.915 &  1.000 &  0.228 &  0.872 &  1.000 \\
#  0.358 &  0.983 &  1.000 &  0.307 &  0.972 &  1.000 \\
#  0.439 &  0.997 &  1.000 &  0.387 &  0.996 &  1.000 \\
#  0.422 &  0.618 &  0.967 &  0.151 &  0.300 &  0.870 \\
#  0.282 &  0.878 &  1.000 &  0.204 &  0.824 &  1.000 \\
#  0.389 &  0.992 &  1.000 &  0.342 &  0.990 &  1.000 \\
#  0.626 &  0.999 &  1.000 &  0.568 &  0.999 &  1.000 \\
# ...

# %%
table41 = pd.DataFrame(np.concatenate((power0[:,2:,0,0,3],power0[:,2:,1,0,3],power0[:,2:,2,0,3],power0[:,2:,3,0,3],power0[:,2:,4,0,3]),0))
table42 = pd.DataFrame(np.concatenate((power0[:,2:,0,1,3],power0[:,2:,1,1,3],power0[:,2:,2,1,3],power0[:,2:,3,1,3],power0[:,2:,4,1,3]),0))
table43 = pd.DataFrame(np.concatenate((power0[:,2:,0,2,3],power0[:,2:,1,2,3],power0[:,2:,2,2,3],power0[:,2:,3,2,3],power0[:,2:,4,2,3]),0))
table4a = pd.concat((table41,table42,table43),1)
table41 = pd.DataFrame(np.concatenate((power1[:,2:,0,0,3],power1[:,2:,1,0,3],power1[:,2:,2,0,3],power1[:,2:,3,0,3],power1[:,2:,4,0,3]),0))
table42 = pd.DataFrame(np.concatenate((power1[:,2:,0,1,3],power1[:,2:,1,1,3],power1[:,2:,2,1,3],power1[:,2:,3,1,3],power1[:,2:,4,1,3]),0))
table43 = pd.DataFrame(np.concatenate((power1[:,2:,0,2,3],power1[:,2:,1,2,3],power1[:,2:,2,2,3],power1[:,2:,3,2,3],power1[:,2:,4,2,3]),0))
table4b = pd.concat((table41,table42,table43),1)
table4 = pd.concat((table4a,table4b),1)
print(pd.DataFrame.to_latex(table4,index=False, header=False))
# Out:
# \begin{tabular}{rrrrrr}
# \toprule
#  0.999 &  1.000 &  1.000 &  0.291 &  0.286 &  0.373 \\
#  0.731 &  0.875 &  0.982 &  0.162 &  0.252 &  0.664 \\
#  0.482 &  0.729 &  0.996 &  0.127 &  0.320 &  0.913 \\
#  0.330 &  0.671 &  0.996 &  0.150 &  0.425 &  0.984 \\
#  0.328 &  0.767 &  1.000 &  0.170 &  0.610 &  1.000 \\
#  0.266 &  0.840 &  1.000 &  0.162 &  0.702 &  1.000 \\
#  0.893 &  0.952 &  0.996 &  0.130 &  0.188 &  0.555 \\
#  0.471 &  0.802 &  0.996 &  0.203 &  0.496 &  0.982 \\
#  0.351 &  0.828 &  1.000 &  0.228 &  0.688 &  1.000 \\
#  0.327 &  0.947 &  1.000 &  0.255 &  0.915 &  1.000 \\
#  0.355 &  0.982 &  1.000 &  0.293 &  0.974 &  1.000 \\
#  0.399 &  0.994 &  1.000 &  0.346 &  0.993 &  1.000 \\
#  0.542 &  0.851 &  1.000 &  0.234 &  0.535 &  0.991 \\
#  0.380 &  0.931 &  1.000 &  0.270 &  0.888 &  1.000 \\
#  0.396 &  0.989 &  1.000 &  0.348 &  0.989 &  1.000 \\
#  0.564 &  0.999 &  1.000 &  0.492 &  0.999 &  1.000 \\
# ...
